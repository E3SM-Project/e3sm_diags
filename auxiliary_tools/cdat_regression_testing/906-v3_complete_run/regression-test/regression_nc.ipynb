# %% [markdown]
# # CDAT Migration Regression Testing Notebook (`.nc` files)
#
# This notebook is used to perform regression testing between the development and
# production versions of a diagnostic set.
#
# ## How it works
#
# It compares the relative differences (%) between ref and test variables between
# the dev and `main` branches.
#
# ## How to use
#
# PREREQUISITE: The diagnostic set's netCDF stored in `.json` files in two directories
# (dev and `main` branches).
#
# 1. Make a copy of this notebook under `auxiliary_tools/cdat_regression_testing/<DIR_NAME>`.
# 2. Run `mamba create -n cdat_regression_test -y -c conda-forge "python<3.12" xarray netcdf4 dask pandas matplotlib-base ipykernel`
# 3. Run `mamba activate cdat_regression_test`
# 4. Update `SET_DIR` and `SET_NAME` in the copy of your notebook.
# 5. Run all cells IN ORDER.
# 6. Review results for any outstanding differences (>=1e-5 relative tolerance).
#    - Debug these differences (e.g., bug in metrics functions, incorrect variable references, etc.)

# %% [markdown]
# ## Setup Code

# %%
import glob
from typing import List

import numpy as np
import xarray as xr

from e3sm_diags.derivations.derivations import DERIVED_VARIABLES

# The path to the development data.
DEV_DIR = "25-01-06-branch-907-no-arm-diags"
DEV_PATH = f"/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/{DEV_DIR}/"
DEV_GLOB = sorted(glob.glob(DEV_PATH + "**/**/*.nc"))
DEV_NUM_FILES = len(DEV_GLOB)

# The path to the production data to compare against.
MAIN_DIR = "v2.12.1v2"
MAIN_PATH = f"/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/{MAIN_DIR}/"
MAIN_GLOB = sorted(glob.glob(MAIN_PATH + "**/**/*.nc"))
MAIN_NUM_FILES = len(MAIN_GLOB)


def _remove_unwanted_files(file_glob: List[str]) -> List[str]:
    """Remove files that we don't want to compare.

    * area_mean_time_series -- `main` does not generate netCDF
    * enso_diags -- `main` does not generate netCDF
    * qbo -- variable name differs
    * diurnal_cycle -- variable name differs
    * diff -- comparing the difference between regridded files is not helpful
      between branches because of the influence in floating point errors.
    * ERA5_ext-U10-ANN-global_ref and ERA5_ext-U10-JJA-global_ref -- dev
      branch does not generate these files because it is a model-only run.

    Parameters
    ----------
    file_glob : List[str]
        _description_

    Returns
    -------
    List[str]
        _description_
    """

    new_glob = []

    for fp in file_glob:
        if (
            "area_mean_time_series" in fp
            or "enso_diags" in fp
            or "qbo" in fp
            or "diurnal_cycle" in fp
            or "diff" in fp
            or "ERA5_ext-U10-ANN-global_ref" in fp
            or "ERA5_ext-U10-JJA-global_ref" in fp
            or "tropical_subseasonal" in fp
        ):
            continue

        new_glob.append(fp)

    return new_glob


DEV_GLOB = _remove_unwanted_files(DEV_GLOB)
MAIN_GLOB = _remove_unwanted_files(MAIN_GLOB)

# %%
def _get_relative_diffs():
    # The absolute and relative tolerances for the tests.
    ATOL = 0
    RTOL = 1e-4

    results = {
        "missing_files": [],
        "missing_vars": [],
        "matching_files": [],
        "mismatch_errors": [],
        "not_equal_errors": [],
        "key_errors": [],
    }

    for fp_main in MAIN_GLOB:
        fp_dev = fp_main.replace(MAIN_DIR, DEV_DIR)

        if "annual_cycle_zonal_mean" in fp_main:
            if "test.nc" in fp_main:
                fp_dev = fp_dev.replace("test.nc", "ref.nc")
            elif "ref.nc" in fp_main:
                fp_dev = fp_dev.replace("ref.nc", "test.nc")

        try:
            ds1 = xr.open_dataset(fp_dev)
            ds2 = xr.open_dataset(fp_main)
        except FileNotFoundError as e:
            print(f"    {e}")

            if isinstance(e, FileNotFoundError) or isinstance(e, OSError):
                results["missing_files"].append(fp_dev)

            continue

        var_key = fp_main.split("-")[-3]

        # for 3d vars such as T-200
        var_key.isdigit()
        if var_key.isdigit():
            var_key = fp_main.split("-")[-4]

        dev_data = _get_var_data(ds1, var_key)
        main_data = _get_var_data(ds2, var_key)

        if dev_data is None or main_data is None:
            if dev_data is None:
                results["missing_vars"].append(fp_dev)
            elif main_data is None:
                results["missing_vars"].append(fp_main)

            print("    * Could not find variable key in the dataset(s)")

            continue

        try:
            np.testing.assert_allclose(
                dev_data,
                main_data,
                atol=ATOL,
                rtol=RTOL,
            )
            results["matching_files"].append(fp_main)
        except (KeyError, AssertionError) as e:
            print("Comparing:")
            print(f"    * {fp_dev}")
            print(f"    * {fp_main}")
            print(f"    * var_key: {var_key}")
            msg = str(e)

            print(f"    {msg}")

            if "mismatch" in msg:
                results["mismatch_errors"].append(fp_dev)
            elif "Not equal to tolerance" in msg:
                results["not_equal_errors"].append(fp_dev)

    return results


def _get_var_data(ds: xr.Dataset, var_key: str) -> np.ndarray:
    """Get the variable data using a list of matching keys.

    The `main` branch saves the dataset using the original variable name,
    while the dev branch saves the variable with the derived variable name.
    The dev branch is performing the expected behavior here.

    Parameters
    ----------
    ds : xr.Dataset
        _description_
    var_key : str
        _description_

    Returns
    -------
    np.ndarray
        _description_
    """

    data = None

    try:
        data = ds[var_key].values
    except KeyError:
        try:
            var_keys = DERIVED_VARIABLES[var_key].keys()
        except KeyError:
            var_keys = DERIVED_VARIABLES[var_key.upper()].keys()

        var_keys = [var_key] + list(sum(var_keys, ()))

        for key in var_keys:
            if key in ds.data_vars.keys():
                data = ds[key].values
                break

    return data

# %%
def _check_if_files_found():
    if DEV_NUM_FILES == 0 or MAIN_NUM_FILES == 0:
        raise IOError(
            "No files found at DEV_DIR and/or MAIN_DIR. "
            f"Please check {DEV_PATH} and {MAIN_DIR}."
        )


def _check_if_matching_filecount():
    if DEV_NUM_FILES != MAIN_NUM_FILES:
        raise IOError(
            "Number of files do not match at DEV_DIR and MAIN_DIR "
            f"({DEV_NUM_FILES} vs. {MAIN_NUM_FILES})."
        )

    print(f"Matching file count ({DEV_NUM_FILES} and {MAIN_NUM_FILES}).")


def _check_if_missing_files():
    missing_dev_files = []
    missing_main_files = []

    for fp_main in MAIN_GLOB:
        fp_dev = fp_main.replace(MAIN_DIR, DEV_DIR)

        if fp_dev not in DEV_GLOB:
            missing_dev_files.append(fp_dev)

    for fp_dev in DEV_GLOB:
        fp_main = fp_dev.replace(DEV_DIR, MAIN_DIR)

        if fp_main not in MAIN_GLOB:
            missing_main_files.append(fp_main)

    return missing_dev_files, missing_main_files

# %% [markdown]
# ## 1. Check for matching and equal number of files

# %%
_check_if_files_found()

# %%
DEV_GLOB = [fp for fp in DEV_GLOB if "diff.nc" not in fp]
MAIN_GLOB = [fp for fp in MAIN_GLOB if "diff.nc" not in fp]

# %%
len(DEV_GLOB), len(MAIN_GLOB)
# Out:
# (521, 590)

# %%
missing_dev_files, missing_main_files = _check_if_missing_files()

print(f"Missing dev files: {len(missing_dev_files)}")
print(f"Missing main files: {len(missing_main_files)}")
# Out:
# Missing dev files: 69
# Missing main files: 0

# %% [markdown]
# ### Check missing main files (not concerned)
#
# Results:
#
# - The missing files are due to a recent .cfg update in [PR #830](https://github.com/E3SM-Project/e3sm_diags/pull/830)

# %%
missing_main_files
# Out:
# []

# %% [markdown]
# ### Check missing dev files:
#
# Results:
#
# - The missing reference files are due to not saving them out to netCDF since they are the same as the test files (skipped, model-only run)

# %%
missing_dev_files
# Out:
# ['/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-OMEGA-200-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-OMEGA-500-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-OMEGA-850-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-PSL-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-TAUXY-ANN-ocean_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-TMQ-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-TREFHT-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-TREFHT-ANN-land_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-TREFMNAV-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-TREFMXAV-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/lat_lon/MERRA2/MERRA2-Z3-500-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/meridional_mean_2d/MERRA2/MERRA2-OMEGA-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/meridional_mean_2d/MERRA2/MERRA2-OMEGA-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/meridional_mean_2d/MERRA2/MERRA2-RELHUM-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/meridional_mean_2d/MERRA2/MERRA2-RELHUM-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-PSL-ANN-polar_N_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-PSL-ANN-polar_N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-PSL-ANN-polar_S_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-PSL-ANN-polar_S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TAUXY-ANN-polar_N_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TAUXY-ANN-polar_N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TAUXY-ANN-polar_S_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TAUXY-ANN-polar_S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TMQ-ANN-polar_N_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TMQ-ANN-polar_N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TMQ-ANN-polar_S_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TMQ-ANN-polar_S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFHT-ANN-polar_N_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFHT-ANN-polar_N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFHT-ANN-polar_S_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFHT-ANN-polar_S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFMNAV-ANN-polar_N_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFMNAV-ANN-polar_N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFMNAV-ANN-polar_S_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFMNAV-ANN-polar_S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFMXAV-ANN-polar_N_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFMXAV-ANN-polar_N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFMXAV-ANN-polar_S_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-TREFMXAV-ANN-polar_S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-Z3-500-ANN-polar_N_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-Z3-500-ANN-polar_N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-Z3-500-ANN-polar_S_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/polar/MERRA2/MERRA2-Z3-500-ANN-polar_S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d/MERRA2/MERRA2-H2OLNZ-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d/MERRA2/MERRA2-H2OLNZ-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d/MERRA2/MERRA2-OMEGA-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d/MERRA2/MERRA2-OMEGA-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d/MERRA2/MERRA2-Q-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d/MERRA2/MERRA2-Q-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d/MERRA2/MERRA2-RELHUM-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d/MERRA2/MERRA2-RELHUM-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d_stratosphere/MERRA2/MERRA2-H2OLNZ-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d_stratosphere/MERRA2/MERRA2-H2OLNZ-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d_stratosphere/MERRA2/MERRA2-OMEGA-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d_stratosphere/MERRA2/MERRA2-OMEGA-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d_stratosphere/MERRA2/MERRA2-Q-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d_stratosphere/MERRA2/MERRA2-Q-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d_stratosphere/MERRA2/MERRA2-RELHUM-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_2d_stratosphere/MERRA2/MERRA2-RELHUM-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-TMQ-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-TMQ-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-TREFHT-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-TREFHT-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-TREFMNAV-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-TREFMNAV-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-TREFMXAV-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-TREFMXAV-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-Z3-500-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907-no-arm-diags/zonal_mean_xy/MERRA2/MERRA2-Z3-500-ANN-global_test.nc']

# %% [markdown]
# ## 2 Compare the netCDF files between branches
#
# - Compare "ref" and "test" files
# - "diff" files are ignored because getting relative diffs for these does not make sense (relative diff will be above tolerance)

# %%
results = _get_relative_diffs()
# Out:
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/COREv2_Flux/COREv2_Flux-PminusE-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/COREv2_Flux/COREv2_Flux-PminusE-ANN-global_test.nc
#     * var_key: PminusE
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 47 / 64800 (0.0725%)
# Max absolute difference: 1.8531864e-06
# Max relative difference: 0.00244282
#  x: array([[0.154003, 0.154003, 0.154003, ..., 0.188599, 0.188599, 0.188599],
#        [0.13969 , 0.139701, 0.139724, ..., 0.162309, 0.162268, 0.162247],
#        [0.12946 , 0.12946 , 0.12946 , ..., 0.143414, 0.143414, 0.143414],...
#  y: array([[0.154003, 0.154003, 0.154003, ..., 0.188599, 0.188599, 0.188599],
#        [0.13969 , 0.139701, 0.139724, ..., 0.162309, 0.162268, 0.162247],
#        [0.12946 , 0.12946 , 0.12946 , ..., 0.143414, 0.143414, 0.143414],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_9.4_MISR-ANN-global_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_9.4_MISR-ANN-global_ref.nc
#     * var_key: CLDLOW_TAU1.3_9.4_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 39151 / 64800 (60.4%)
# Max absolute difference: 22.41111565
# Max relative difference: 0.6832267
#  x: array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],...
#  y: array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_9.4_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_9.4_MISR-ANN-global_test.nc
#     * var_key: CLDLOW_TAU1.3_9.4_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 35 / 64800 (0.054%)
# Max absolute difference: 0.11488533
# Max relative difference: 0.01234799
#  x: array([[ 0.049145,  0.049145,  0.049145, ...,  0.401588,  0.401588,
#          0.401588],
#        [ 0.128408,  0.128346,  0.128222, ...,  0.492608,  0.492751,...
#  y: array([[ 0.049145,  0.049145,  0.049145, ...,  0.401588,  0.401588,
#          0.401588],
#        [ 0.128408,  0.128346,  0.128222, ...,  0.492608,  0.492751,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_MISR-ANN-global_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_MISR-ANN-global_ref.nc
#     * var_key: CLDLOW_TAU1.3_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 39226 / 64800 (60.5%)
# Max absolute difference: 37.67312241
# Max relative difference: 0.62295458
#  x: array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],...
#  y: array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_MISR-ANN-global_test.nc
#     * var_key: CLDLOW_TAU1.3_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 33 / 64800 (0.0509%)
# Max absolute difference: 0.11487961
# Max relative difference: 0.0051227
#  x: array([[4.914530e-02, 4.914530e-02, 4.914530e-02, ..., 4.015881e-01,
#         4.015881e-01, 4.015881e-01],
#        [1.284084e-01, 1.283463e-01, 1.282219e-01, ..., 4.943842e-01,...
#  y: array([[4.914530e-02, 4.914530e-02, 4.914530e-02, ..., 4.015881e-01,
#         4.015881e-01, 4.015881e-01],
#        [1.284084e-01, 1.283463e-01, 1.282219e-01, ..., 4.943842e-01,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU9.4_MISR-ANN-global_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/Cloud MISR/MISRCOSP-CLDLOW_TAU9.4_MISR-ANN-global_ref.nc
#     * var_key: CLDLOW_TAU9.4_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 38772 / 64800 (59.8%)
# Max absolute difference: 31.08518791
# Max relative difference: 0.96666667
#  x: array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],...
#  y: array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/Cloud MISR/MISRCOSP-CLDTOT_TAU1.3_9.4_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/Cloud MISR/MISRCOSP-CLDTOT_TAU1.3_9.4_MISR-ANN-global_test.nc
#     * var_key: CLDTOT_TAU1.3_9.4_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 33 / 64800 (0.0509%)
# Max absolute difference: 0.11488724
# Max relative difference: 0.00613982
#  x: array([[ 1.693131,  1.693131,  1.693131, ...,  3.310595,  3.310595,
#          3.310595],
#        [ 1.94408 ,  1.943883,  1.943489, ...,  3.309429,  3.309427,...
#  y: array([[ 1.693131,  1.693131,  1.693131, ...,  3.310595,  3.310595,
#          3.310595],
#        [ 1.944079,  1.943883,  1.943489, ...,  3.309429,  3.309428,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/Cloud MISR/MISRCOSP-CLDTOT_TAU1.3_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/Cloud MISR/MISRCOSP-CLDTOT_TAU1.3_MISR-ANN-global_test.nc
#     * var_key: CLDTOT_TAU1.3_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 30 / 64800 (0.0463%)
# Max absolute difference: 0.11487579
# Max relative difference: 0.00290628
#  x: array([[ 1.696183,  1.696183,  1.696183, ...,  3.3167  ,  3.3167  ,
#          3.3167  ],
#        [ 1.945352,  1.945156,  1.944765, ...,  3.320152,  3.320158,...
#  y: array([[ 1.696183,  1.696183,  1.696183, ...,  3.3167  ,  3.3167  ,
#          3.3167  ],
#        [ 1.945352,  1.945157,  1.944765, ...,  3.320152,  3.320158,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-NET_FLUX_SRF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/ERA5/ERA5-NET_FLUX_SRF-ANN-global_test.nc
#     * var_key: NET_FLUX_SRF
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 194 / 64800 (0.299%)
# Max absolute difference: 3.7033797e-05
# Max relative difference: 0.12149699
#  x: array([[-0.169821, -0.169821, -0.169821, ..., -0.364244, -0.364244,
#         -0.364244],
#        [-0.201356, -0.201327, -0.201281, ..., -0.330032, -0.329979,...
#  y: array([[-0.169821, -0.169821, -0.169821, ..., -0.364244, -0.364244,
#         -0.364244],
#        [-0.201356, -0.201328, -0.201281, ..., -0.330033, -0.329979,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-OMEGA-200-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/ERA5/ERA5-OMEGA-200-ANN-global_test.nc
#     * var_key: OMEGA
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 1 / 64800 (0.00154%)
# Max absolute difference: 9.84166527e-06
# Max relative difference: 0.00094765
#  x: array([[1.190626, 1.190626, 1.190626, ..., 0.516767, 0.516767, 0.516767],
#        [1.267546, 1.267486, 1.267367, ..., 0.859722, 0.860258, 0.860526],
#        [1.321632, 1.321632, 1.321632, ..., 1.10376 , 1.10376 , 1.10376 ],...
#  y: array([[1.190626, 1.190626, 1.190626, ..., 0.516767, 0.516767, 0.516767],
#        [1.267546, 1.267486, 1.267367, ..., 0.859722, 0.860258, 0.860526],
#        [1.321632, 1.321632, 1.321632, ..., 1.10376 , 1.10376 , 1.10376 ],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-OMEGA-500-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/ERA5/ERA5-OMEGA-500-ANN-global_test.nc
#     * var_key: OMEGA
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 3 / 64800 (0.00463%)
# Max absolute difference: 2.88457862e-05
# Max relative difference: 0.00474639
#  x: array([[2.793445, 2.793445, 2.793445, ..., 2.021953, 2.021953, 2.021953],
#        [3.328145, 3.327742, 3.326934, ..., 5.38816 , 5.393232, 5.395765],
#        [3.688833, 3.688833, 3.688833, ..., 7.626963, 7.626963, 7.626963],...
#  y: array([[2.793444, 2.793444, 2.793444, ..., 2.021952, 2.021952, 2.021952],
#        [3.328145, 3.327742, 3.326934, ..., 5.388161, 5.393232, 5.395765],
#        [3.688833, 3.688833, 3.688833, ..., 7.626963, 7.626963, 7.626963],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-OMEGA-850-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/ERA5/ERA5-OMEGA-850-ANN-global_test.nc
#     * var_key: OMEGA
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 23 / 64800 (0.0355%)
# Max absolute difference: 0.00080873
# Max relative difference: 0.00474267
#  x: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
#  y: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-TAUXY-ANN-ocean_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/ERA5/ERA5-TAUXY-ANN-ocean_ref.nc
#     * var_key: TAUXY
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# x and y nan location mismatch:
#  x: array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],...
#  y: array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-TREFHT-ANN-land_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/ERA5/ERA5-TREFHT-ANN-land_ref.nc
#     * var_key: TREFHT
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# x and y nan location mismatch:
#  x: array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,...
#  y: array([[-45.43447 , -45.43447 , -45.43447 , ..., -45.43447 , -45.43447 ,
#         -45.43447 ],
#        [-45.000128, -44.998984, -44.997885, ..., -45.001944, -45.001349,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-U-850-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/ERA5/ERA5-U-850-ANN-global_test.nc
#     * var_key: U
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 22 / 64800 (0.034%)
# Max absolute difference: 2.11642471e-05
# Max relative difference: 0.0052301
#  x: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
#  y: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/GPCP_OAFLux/GPCP_OAFLux-PminusE-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/GPCP_OAFLux/GPCP_OAFLux-PminusE-ANN-global_test.nc
#     * var_key: PminusE
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 47 / 64800 (0.0725%)
# Max absolute difference: 1.8531864e-06
# Max relative difference: 0.00244282
#  x: array([[0.154003, 0.154003, 0.154003, ..., 0.188599, 0.188599, 0.188599],
#        [0.13969 , 0.139701, 0.139724, ..., 0.162309, 0.162268, 0.162247],
#        [0.12946 , 0.12946 , 0.12946 , ..., 0.143414, 0.143414, 0.143414],...
#  y: array([[0.154003, 0.154003, 0.154003, ..., 0.188599, 0.188599, 0.188599],
#        [0.13969 , 0.139701, 0.139724, ..., 0.162309, 0.162268, 0.162247],
#        [0.12946 , 0.12946 , 0.12946 , ..., 0.143414, 0.143414, 0.143414],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/GPCP_v2.3/GPCP_v2.3-PRECT-ANN-global_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/GPCP_v2.3/GPCP_v2.3-PRECT-ANN-global_ref.nc
#     * var_key: PRECT
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 9787 / 10368 (94.4%)
# Max absolute difference: 0.00390617
# Max relative difference: 0.31244895
#  x: array([[0.3125  , 0.304688, 0.304688, ..., 0.3125  , 0.328125, 0.328125],
#        [0.210938, 0.210938, 0.203125, ..., 0.210938, 0.21875 , 0.210938],
#        [0.171875, 0.171875, 0.148438, ..., 0.195312, 0.195312, 0.1875  ],...
#  y: array([[0.312092, 0.305849, 0.301169, ..., 0.315146, 0.330876, 0.330014],
#        [0.210044, 0.211685, 0.202171, ..., 0.211803, 0.219721, 0.214471],
#        [0.173898, 0.171273, 0.149807, ..., 0.195412, 0.196494, 0.188691],...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-LHFLX-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-LHFLX-ANN-global_test.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-NET_FLUX_SRF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/MERRA2/MERRA2-NET_FLUX_SRF-ANN-global_test.nc
#     * var_key: NET_FLUX_SRF
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 194 / 64800 (0.299%)
# Max absolute difference: 3.7033797e-05
# Max relative difference: 0.12149699
#  x: array([[-0.169821, -0.169821, -0.169821, ..., -0.364244, -0.364244,
#         -0.364244],
#        [-0.201356, -0.201327, -0.201281, ..., -0.330032, -0.329979,...
#  y: array([[-0.169821, -0.169821, -0.169821, ..., -0.364244, -0.364244,
#         -0.364244],
#        [-0.201356, -0.201328, -0.201281, ..., -0.330033, -0.329979,...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-OMEGA-200-ANN-global_ref.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-OMEGA-200-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/MERRA2/MERRA2-OMEGA-200-ANN-global_test.nc
#     * var_key: OMEGA
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 1 / 64800 (0.00154%)
# Max absolute difference: 9.84166527e-06
# Max relative difference: 0.00094765
#  x: array([[1.190626, 1.190626, 1.190626, ..., 0.516767, 0.516767, 0.516767],
#        [1.267546, 1.267486, 1.267367, ..., 0.859722, 0.860258, 0.860526],
#        [1.321632, 1.321632, 1.321632, ..., 1.10376 , 1.10376 , 1.10376 ],...
#  y: array([[1.190626, 1.190626, 1.190626, ..., 0.516767, 0.516767, 0.516767],
#        [1.267546, 1.267486, 1.267367, ..., 0.859722, 0.860258, 0.860526],
#        [1.321632, 1.321632, 1.321632, ..., 1.10376 , 1.10376 , 1.10376 ],...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-OMEGA-500-ANN-global_ref.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-OMEGA-500-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/MERRA2/MERRA2-OMEGA-500-ANN-global_test.nc
#     * var_key: OMEGA
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 3 / 64800 (0.00463%)
# Max absolute difference: 2.88457862e-05
# Max relative difference: 0.00474639
#  x: array([[2.793445, 2.793445, 2.793445, ..., 2.021953, 2.021953, 2.021953],
#        [3.328145, 3.327742, 3.326934, ..., 5.38816 , 5.393232, 5.395765],
#        [3.688833, 3.688833, 3.688833, ..., 7.626963, 7.626963, 7.626963],...
#  y: array([[2.793444, 2.793444, 2.793444, ..., 2.021952, 2.021952, 2.021952],
#        [3.328145, 3.327742, 3.326934, ..., 5.388161, 5.393232, 5.395765],
#        [3.688833, 3.688833, 3.688833, ..., 7.626963, 7.626963, 7.626963],...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-OMEGA-850-ANN-global_ref.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-OMEGA-850-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/MERRA2/MERRA2-OMEGA-850-ANN-global_test.nc
#     * var_key: OMEGA
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 23 / 64800 (0.0355%)
# Max absolute difference: 0.00080873
# Max relative difference: 0.00474267
#  x: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
#  y: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-PSL-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-PSL-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-SHFLX-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-SHFLX-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-TAUXY-ANN-ocean_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-TMQ-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-TREFHT-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-TREFHT-ANN-land_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-TREFMNAV-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-TREFMXAV-ANN-global_ref.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-U-850-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/MERRA2/MERRA2-U-850-ANN-global_test.nc
#     * var_key: U
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 22 / 64800 (0.034%)
# Max absolute difference: 2.11642471e-05
# Max relative difference: 0.0052301
#  x: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
#  y: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-Z3-500-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/meridional_mean_2d/MERRA2/MERRA2-OMEGA-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/meridional_mean_2d/MERRA2/MERRA2-OMEGA-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/meridional_mean_2d/MERRA2/MERRA2-RELHUM-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/meridional_mean_2d/MERRA2/MERRA2-RELHUM-ANN-global_test.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/ERA5/ERA5-U-850-ANN-polar_N_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/polar/ERA5/ERA5-U-850-ANN-polar_N_test.nc
#     * var_key: U
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 4 / 14400 (0.0278%)
# Max absolute difference: 1.0866463e-05
# Max relative difference: 0.00062261
#  x: array([[ 5.20822 ,  5.208802,  5.213029, ...,  5.280987,  5.219766,
#          5.206481],
#        [ 5.193393,  5.201545,  5.26418 , ...,  5.211428,  5.168795,...
#  y: array([[ 5.20822 ,  5.208802,  5.213029, ...,  5.280987,  5.219766,
#          5.206481],
#        [ 5.193392,  5.201545,  5.26418 , ...,  5.211428,  5.168795,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/ERA5/ERA5-U-850-ANN-polar_S_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/polar/ERA5/ERA5-U-850-ANN-polar_S_test.nc
#     * var_key: U
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 4 / 12600 (0.0317%)
# Max absolute difference: 2.11642471e-05
# Max relative difference: 0.00247758
#  x: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
#  y: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/GPCP_v2.3/GPCP_v2.3-PRECT-ANN-polar_N_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/polar/GPCP_v2.3/GPCP_v2.3-PRECT-ANN-polar_N_ref.nc
#     * var_key: PRECT
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 2215 / 2304 (96.1%)
# Max absolute difference: 0.00390585
# Max relative difference: 0.01532052
#  x: array([[2.203125, 2.523438, 2.71875 , ..., 3.203125, 3.640625, 2.34375 ],
#        [2.0625  , 2.671875, 2.796875, ..., 3.273438, 3.65625 , 2.640625],
#        [3.054688, 3.109375, 2.757812, ..., 6.257812, 4.070312, 2.609375],...
#  y: array([[2.206489, 2.521486, 2.716957, ..., 3.202984, 3.642795, 2.344619],
#        [2.061055, 2.668753, 2.799254, ..., 3.275738, 3.652374, 2.640937],
#        [3.053188, 3.105949, 2.756729, ..., 6.257159, 4.073194, 2.610571],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/GPCP_v2.3/GPCP_v2.3-PRECT-ANN-polar_S_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/polar/GPCP_v2.3/GPCP_v2.3-PRECT-ANN-polar_S_ref.nc
#     * var_key: PRECT
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 1944 / 2016 (96.4%)
# Max absolute difference: 0.00390354
# Max relative difference: 0.07498789
#  x: array([[0.3125  , 0.304688, 0.304688, ..., 0.3125  , 0.328125, 0.328125],
#        [0.210938, 0.210938, 0.203125, ..., 0.210938, 0.21875 , 0.210938],
#        [0.171875, 0.171875, 0.148438, ..., 0.195312, 0.195312, 0.1875  ],...
#  y: array([[0.312092, 0.305849, 0.301169, ..., 0.315146, 0.330876, 0.330014],
#        [0.210044, 0.211685, 0.202171, ..., 0.211803, 0.219721, 0.214471],
#        [0.173898, 0.171273, 0.149807, ..., 0.195412, 0.196494, 0.188691],...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-PSL-ANN-polar_N_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-PSL-ANN-polar_N_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-PSL-ANN-polar_S_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-PSL-ANN-polar_S_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TAUXY-ANN-polar_N_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TAUXY-ANN-polar_N_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TAUXY-ANN-polar_S_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TAUXY-ANN-polar_S_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TMQ-ANN-polar_N_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TMQ-ANN-polar_N_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TMQ-ANN-polar_S_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TMQ-ANN-polar_S_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFHT-ANN-polar_N_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFHT-ANN-polar_N_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFHT-ANN-polar_S_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFHT-ANN-polar_S_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFMNAV-ANN-polar_N_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFMNAV-ANN-polar_N_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFMNAV-ANN-polar_S_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFMNAV-ANN-polar_S_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFMXAV-ANN-polar_N_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFMXAV-ANN-polar_N_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFMXAV-ANN-polar_S_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-TREFMXAV-ANN-polar_S_test.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-U-850-ANN-polar_N_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/polar/MERRA2/MERRA2-U-850-ANN-polar_N_test.nc
#     * var_key: U
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 4 / 14400 (0.0278%)
# Max absolute difference: 1.0866463e-05
# Max relative difference: 0.00062261
#  x: array([[ 5.20822 ,  5.208802,  5.213029, ...,  5.280987,  5.219766,
#          5.206481],
#        [ 5.193393,  5.201545,  5.26418 , ...,  5.211428,  5.168795,...
#  y: array([[ 5.20822 ,  5.208802,  5.213029, ...,  5.280987,  5.219766,
#          5.206481],
#        [ 5.193392,  5.201545,  5.26418 , ...,  5.211428,  5.168795,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-U-850-ANN-polar_S_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/polar/MERRA2/MERRA2-U-850-ANN-polar_S_test.nc
#     * var_key: U
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 4 / 12600 (0.0317%)
# Max absolute difference: 2.11642471e-05
# Max relative difference: 0.00247758
#  x: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
#  y: array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-Z3-500-ANN-polar_N_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-Z3-500-ANN-polar_N_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-Z3-500-ANN-polar_S_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/MERRA2/MERRA2-Z3-500-ANN-polar_S_test.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/ERA5/ERA5-OMEGA-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/zonal_mean_2d/ERA5/ERA5-OMEGA-ANN-global_test.nc
#     * var_key: OMEGA
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 1 / 3600 (0.0278%)
# Max absolute difference: 0.00010383
# Max relative difference: 0.00027003
#  x: array([[ 0.025166,  0.023099,  0.017925, ..., -0.461106, -0.460638,
#         -0.460472],
#        [ 0.171211,  0.167126,  0.156825, ..., -0.220465, -0.212462,...
#  y: array([[ 0.025166,  0.023099,  0.017925, ..., -0.461106, -0.460638,
#         -0.460472],
#        [ 0.171211,  0.167126,  0.156825, ..., -0.220465, -0.212462,...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/MERRA2/MERRA2-H2OLNZ-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/MERRA2/MERRA2-H2OLNZ-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/MERRA2/MERRA2-OMEGA-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/MERRA2/MERRA2-OMEGA-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/MERRA2/MERRA2-Q-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/MERRA2/MERRA2-Q-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/MERRA2/MERRA2-RELHUM-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/MERRA2/MERRA2-RELHUM-ANN-global_test.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/ERA5/ERA5-H2OLNZ-ANN-global_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/zonal_mean_2d_stratosphere/ERA5/ERA5-H2OLNZ-ANN-global_ref.nc
#     * var_key: H2OLNZ
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 7210 / 7210 (100%)
# Max absolute difference: 6.37594484
# Max relative difference: 0.99937867
#  x: array([[0.003862, 0.003862, 0.003863, ..., 0.003912, 0.003911, 0.003911],
#        [0.003845, 0.003845, 0.003845, ..., 0.003878, 0.003878, 0.003877],
#        [0.003819, 0.003819, 0.003819, ..., 0.00385 , 0.00385 , 0.00385 ],...
#  y: array([[6.216128, 6.216276, 6.216544, ..., 6.29543 , 6.29478 , 6.29478 ],
#        [6.188974, 6.188632, 6.188663, ..., 6.241248, 6.240764, 6.240415],
#        [6.146792, 6.14647 , 6.146134, ..., 6.196124, 6.196318, 6.19623 ],...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/ERA5/ERA5-H2OLNZ-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/zonal_mean_2d_stratosphere/ERA5/ERA5-H2OLNZ-ANN-global_test.nc
#     * var_key: H2OLNZ
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 1800 / 1800 (100%)
# Max absolute difference: 6.73113556
# Max relative difference: 0.99937867
#  x: array([[0.004149, 0.004149, 0.004149, ..., 0.004144, 0.004144, 0.004144],
#        [0.004097, 0.004097, 0.004097, ..., 0.004091, 0.004092, 0.004092],
#        [0.004017, 0.004017, 0.004017, ..., 0.004013, 0.004013, 0.004013],...
#  y: array([[6.677132, 6.677097, 6.677016, ..., 6.669499, 6.669646, 6.669721],
#        [6.59368 , 6.59364 , 6.593552, ..., 6.5849  , 6.585056, 6.585129],
#        [6.465186, 6.465079, 6.464847, ..., 6.458621, 6.458826, 6.458924],...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/MERRA2/MERRA2-H2OLNZ-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/MERRA2/MERRA2-H2OLNZ-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/MERRA2/MERRA2-OMEGA-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/MERRA2/MERRA2-OMEGA-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/MERRA2/MERRA2-Q-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/MERRA2/MERRA2-Q-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/MERRA2/MERRA2-RELHUM-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/MERRA2/MERRA2-RELHUM-ANN-global_test.nc'
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/MERRA2/MERRA2-U-ANN-global_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/zonal_mean_2d_stratosphere/MERRA2/MERRA2-U-ANN-global_ref.nc
#     * var_key: U
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 16 / 3610 (0.443%)
# Max absolute difference: 1.0069872e-07
# Max relative difference: 1.48305291
#  x: array([[-8.003553e-08,  8.746594e-01,  1.610782e+00, ...,  9.277452e-01,
#          4.884759e-01,  6.868504e-08],
#        [ 2.653300e-08,  8.899245e-01,  1.641026e+00, ...,  9.164927e-01,...
#  y: array([[-8.003553e-08,  8.746594e-01,  1.610782e+00, ...,  9.277452e-01,
#          4.884759e-01,  6.868504e-08],
#        [ 3.507194e-08,  8.899245e-01,  1.641026e+00, ...,  9.164927e-01,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_9.4_MISR-ANN-global_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/zonal_mean_xy/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_9.4_MISR-ANN-global_ref.nc
#     * var_key: CLDLOW_TAU1.3_9.4_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 161 / 180 (89.4%)
# Max absolute difference: 5.22607951
# Max relative difference: 0.14372237
#  x: array([      nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#        27.607403, 26.281943, 26.594026, 25.62963 , 24.946797, 25.409239,...
#  y: array([      nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#        29.236507, 28.109412, 28.533893, 27.251634, 26.469386, 26.97218 ,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_MISR-ANN-global_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/zonal_mean_xy/Cloud MISR/MISRCOSP-CLDLOW_TAU1.3_MISR-ANN-global_ref.nc
#     * var_key: CLDLOW_TAU1.3_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 161 / 180 (89.4%)
# Max absolute difference: 9.42316729
# Max relative difference: 0.20406107
#  x: array([      nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#        50.525568, 52.10918 , 52.191102, 52.493405, 50.181182, 50.357442,...
#  y: array([      nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#        53.769157, 55.229167, 55.455046, 55.463217, 53.257188, 53.239823,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/Cloud MISR/MISRCOSP-CLDLOW_TAU9.4_MISR-ANN-global_ref.nc
#     * /global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/zonal_mean_xy/Cloud MISR/MISRCOSP-CLDLOW_TAU9.4_MISR-ANN-global_ref.nc
#     * var_key: CLDLOW_TAU9.4_MISR
#
# Not equal to tolerance rtol=0.0001, atol=0
#
# Mismatched elements: 161 / 180 (89.4%)
# Max absolute difference: 4.19708782
# Max relative difference: 0.42758281
#  x: array([      nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#        22.918165, 25.827236, 25.597075, 26.863775, 25.234384, 24.948203,...
#  y: array([      nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#        24.53265 , 27.119755, 26.921153, 28.211582, 26.787802, 26.267643,...
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-TMQ-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-TMQ-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-TREFHT-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-TREFHT-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-TREFMNAV-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-TREFMNAV-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-TREFMXAV-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-TREFMXAV-ANN-global_test.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-Z3-500-ANN-global_ref.nc'
#     [Errno 2] No such file or directory: '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_xy/MERRA2/MERRA2-Z3-500-ANN-global_test.nc'

# %%
import pandas as pd

(
    missing_files,
    missing_vars,
    matching_files,
    mismatch_errors,
    not_equal_errors,
    key_errors,
) = results.values()

# %%
# Assuming these variables are defined in your notebook
matching_files_count = len(matching_files)
missing_vars_count = len(missing_vars)
mismatch_errors_count = len(mismatch_errors)
not_equal_errors_count = len(not_equal_errors)
key_errors_count = len(key_errors)
missing_files_count = len(missing_files)

sum_files_compared = (
    matching_files_count
    + missing_vars_count
    + mismatch_errors_count
    + not_equal_errors_count
    + key_errors_count
    + missing_files_count
)

pct_match = (matching_files_count / sum_files_compared) * 100

# Collect statistics into a dictionary
statistics = {
    "stat_name": [
        "matching_files_count",
        "missing_vars_count",
        "mismatch_errors_count",
        "not_equal_errors_count",
        "key_errors_count",
        "missing_files_count",
    ],
    "value": [
        matching_files_count,
        missing_vars_count,
        mismatch_errors_count,
        not_equal_errors_count,
        key_errors_count,
        missing_files_count,
    ],
    "pct": [
        matching_files_count / sum_files_compared,
        missing_vars_count / sum_files_compared,
        mismatch_errors_count / sum_files_compared,
        not_equal_errors_count / sum_files_compared,
        key_errors_count / sum_files_compared,
        missing_files_count / sum_files_compared,
    ],
}

# Convert the dictionary to a pandas DataFrame
df = pd.DataFrame(statistics)

# Display the DataFrame
print(df)
# Out:
#                 stat_name  value       pct
# 0    matching_files_count    481  0.815254
# 1      missing_vars_count      0  0.000000
# 2   mismatch_errors_count      2  0.003390
# 3  not_equal_errors_count     33  0.055932
# 4        key_errors_count      0  0.000000
# 5     missing_files_count     74  0.125424

# %% [markdown]
# ### Not Equal Errors
#
# - Note, some files are omitted due to known root causes to the diffs (not a concern)

# %%
not_equal_errors = [
    f
    for f in not_equal_errors
    # https://github.com/E3SM-Project/e3sm_diags/issues/797
    if "MISRCOSP-CLDLOW_TAU1.3_9.4_MISR" not in f
    and "MISRCOSP-CLDLOW_TAU1.3_MISR" not in f
    and "MISRCOSP-CLDLOW_TAU9.4_MISR" not in f
    # only 1 mismatching element with 1e-4 tolerance
    and "ERA5-OMEGA-JJA" not in f and "MERRA2-OMEGA-JJA" not in f
    # https://github.com/E3SM-Project/e3sm_diags/issues/787
    and "MERRA2-U" not in f
    # https://github.com/E3SM-Project/e3sm_diags/issues/852
    and "AOD_550" not in f
]

# %%
not_equal_errors
# Out:
# ['/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/COREv2_Flux/COREv2_Flux-PminusE-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/Cloud MISR/MISRCOSP-CLDTOT_TAU1.3_9.4_MISR-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/Cloud MISR/MISRCOSP-CLDTOT_TAU1.3_MISR-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-NET_FLUX_SRF-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-OMEGA-200-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-OMEGA-500-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-OMEGA-850-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/ERA5/ERA5-U-850-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/GPCP_OAFLux/GPCP_OAFLux-PminusE-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/GPCP_v2.3/GPCP_v2.3-PRECT-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-NET_FLUX_SRF-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-OMEGA-200-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-OMEGA-500-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/MERRA2/MERRA2-OMEGA-850-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/ERA5/ERA5-U-850-ANN-polar_N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/ERA5/ERA5-U-850-ANN-polar_S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/GPCP_v2.3/GPCP_v2.3-PRECT-ANN-polar_N_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/polar/GPCP_v2.3/GPCP_v2.3-PRECT-ANN-polar_S_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d/ERA5/ERA5-OMEGA-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/ERA5/ERA5-H2OLNZ-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/zonal_mean_2d_stratosphere/ERA5/ERA5-H2OLNZ-ANN-global_test.nc']

# %%
import xarray as xr

ds1 = xr.open_dataset(not_equal_errors[-1])
ds2 = xr.open_dataset(not_equal_errors[-1].replace(DEV_DIR, MAIN_DIR))

# %%
ds1 = xr.open_dataset(
    "/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/COREv2_Flux/COREv2_Flux-PminusE-ANN-global_test.nc'"
)
ds2 = xr.open_dataset(
    "/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/COREv2_Flux/COREv2_Flux-PminusE-ANN-global_test.nc"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ds1 = xr.open_dataset(
#       2     "/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/25-01-06-branch-907/lat_lon/COREv2_Flux/COREv2_Flux-PminusE-ANN-global_test.nc'"
#       3 )
#       4 ds2 = xr.open_dataset(
#       5     "/global/cfs/cdirs/e3sm/www/e3sm_diags/complete_run/v2.12.1v2/lat_lon/COREv2_Flux/COREv2_Flux-PminusE-ANN-global_test.nc'",
#       6 )
#
# File /global/u2/v/vo13/mambaforge/envs/e3sm_diags_dev_cm/lib/python3.10/site-packages/xarray/backends/api.py:569, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     566     kwargs.update(backend_kwargs)
#     568 if engine is None:
# --> 569     engine = plugins.guess_engine(filename_or_obj)
#     571 if from_array_kwargs is None:
#     572     from_array_kwargs = {}
#
# File /global/u2/v/vo13/mambaforge/envs/e3sm_diags_dev_cm/lib/python3.10/site-packages/xarray/backends/plugins.py:197, in guess_engine(store_spec)
#     189 else:
#     190     error_msg = (
#     191         "found the following matches with the input file in xarray's IO "
#     192         f"backends: {compatible_engines}. But their dependencies may not be installed, see:\n"
#     193         "https://docs.xarray.dev/en/stable/user-guide/io.html \n"
#     194         "https://docs.xarray.dev/en/stable/getting-started-guide/installing.html"
#     195     )
# --> 197 raise ValueError(error_msg)
#
# ValueError: did not find a match in any of xarray's currently installed IO backends ['netcdf4', 'scipy']. Consider explicitly selecting one of the installed engines via the ``engine`` parameter, or installing additional IO dependencies, see:
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html
# https://docs.xarray.dev/en/stable/user-guide/io.html

# %%
ds1.TREFHT.mean()
# Out:
# <xarray.DataArray 'TREFHT' ()> Size: 4B
# array(-7.496204, dtype=float32)

# %%
ds2.TREFHT.mean()
# Out:
# <xarray.DataArray 'TREFHT' ()> Size: 8B
# array(-7.49620357)
