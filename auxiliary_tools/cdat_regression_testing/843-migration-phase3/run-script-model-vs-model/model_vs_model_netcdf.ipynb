# %% [markdown]
# # CDAT Migration Regression Testing Notebook (`.nc` files)
#
# This notebook is used to perform regression testing between the development and
# production versions of a diagnostic set.
#
# ## How it works
#
# It compares the relative differences (%) between ref and test variables between
# the dev and `main` branches.
#
# ## How to use
#
# PREREQUISITE: The diagnostic set's netCDF stored in `.json` files in two directories
# (dev and `main` branches).
#
# 1. Make a copy of this notebook under `auxiliary_tools/cdat_regression_testing/<DIR_NAME>`.
# 2. Run `mamba create -n cdat_regression_test -y -c conda-forge "python<3.12" xarray netcdf4 dask pandas matplotlib-base ipykernel`
# 3. Run `mamba activate cdat_regression_test`
# 4. Update `SET_DIR` and `SET_NAME` in the copy of your notebook.
# 5. Run all cells IN ORDER.
# 6. Review results for any outstanding differences (>=1e-5 relative tolerance).
#    - Debug these differences (e.g., bug in metrics functions, incorrect variable references, etc.)

# %% [markdown]
# ## Setup Code

# %%
import glob

import numpy as np
import xarray as xr

from e3sm_diags.derivations.derivations import DERIVED_VARIABLES

DEV_DIR = "843-migration-phase3-no-obs"
DEV_PATH = f"/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/{DEV_DIR}/"
DEV_GLOB = sorted(glob.glob(DEV_PATH + "**/**/*.nc"))
DEV_NUM_FILES = len(DEV_GLOB)

MAIN_DIR = "v2_9_0_all_sets_model_vs_model"
MAIN_PATH = f"/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/{MAIN_DIR}/"
MAIN_GLOB = sorted(glob.glob(MAIN_PATH + "**/**/*.nc"))
MAIN_NUM_FILES = len(MAIN_GLOB)

# %%
def _check_if_files_found():
    if DEV_NUM_FILES == 0 or MAIN_NUM_FILES == 0:
        raise IOError(
            "No files found at DEV_PATH and/or MAIN_PATH. "
            f"Please check {DEV_PATH} and {MAIN_PATH}."
        )


def _check_if_matching_filecount():
    if DEV_NUM_FILES != MAIN_NUM_FILES:
        raise IOError(
            "Number of files do not match at DEV_PATH and MAIN_PATH "
            f"({DEV_NUM_FILES} vs. {MAIN_NUM_FILES})."
        )

    print(f"Matching file count ({DEV_NUM_FILES} and {MAIN_NUM_FILES}).")


def _check_if_missing_files():
    missing_dev_files = []
    missing_main_files = []

    for fp_main in MAIN_GLOB:
        fp_dev = fp_main.replace(MAIN_PATH, DEV_PATH)

        if fp_dev not in DEV_GLOB:
            missing_dev_files.append(fp_dev)

    for fp_dev in DEV_GLOB:
        fp_main = fp_dev.replace(DEV_PATH, MAIN_PATH)

        if fp_main not in MAIN_GLOB:
            missing_main_files.append(fp_main)

    return missing_dev_files, missing_main_files

# %%
def _get_relative_diffs():
    # We are mainly focusing on relative tolerance here (in percentage terms).
    atol = 0
    rtol = 1e-5

    results = {
        "missing_files": [],
        "matching_files": [],
        "mismatch_errors": [],
        "not_equal_errors": [],
        "key_errors": [],
    }

    for fp_main in MAIN_GLOB:
        fp_dev = fp_main.replace(f"main/{MAIN_DIR}", DEV_DIR)

        print("Comparing:")
        print(f"    * {fp_dev}")
        print(f"    * {fp_main}")

        try:
            ds1 = xr.open_dataset(fp_dev)
            ds2 = xr.open_dataset(fp_main)
        except FileNotFoundError as e:
            print(f"    {e}")

            if isinstance(e, FileNotFoundError):
                results["missing_files"].append(fp_dev)

            continue

        if "qbo" in fp_main:
            dev_data = ds1["U"].values
            main_data = ds2["U"].values
        else:
            var_key = fp_main.split("-")[-3]
            # for 3d vars such as T-200
            var_key.isdigit()
            if var_key.isdigit():
                var_key = fp_main.split("-")[-4]

            dev_data = _get_var_data(ds1, var_key)
            main_data = _get_var_data(ds2, var_key)

        print(f"    * var_key: {var_key}")

        if dev_data is None or main_data is None:
            print("    * Could not find variable key in the dataset(s)")
            continue

        try:
            np.testing.assert_allclose(
                dev_data,
                main_data,
                atol=atol,
                rtol=rtol,
            )
            results["matching_files"].append(fp_main)
        except (KeyError, AssertionError) as e:
            msg = str(e)

            print(f"    {msg}")
            if "mismatch" in msg:
                results["mismatch_errors"].append(fp_main)
            elif "Not equal to tolerance" in msg:
                results["not_equal_errors"].append(fp_main)
        else:
            print(f"    * All close and within relative tolerance ({rtol})")

    return results


def _get_var_data(ds: xr.Dataset, var_key: str) -> np.ndarray:
    """Get the variable data using a list of matching keys.

    The `main` branch saves the dataset using the original variable name,
    while the dev branch saves the variable with the derived variable name.
    The dev branch is performing the expected behavior here.

    Parameters
    ----------
    ds : xr.Dataset
        _description_
    var_key : str
        _description_

    Returns
    -------
    np.ndarray
        _description_
    """

    data = None

    try:
        var_keys = DERIVED_VARIABLES[var_key].keys()
    except KeyError:
        var_keys = DERIVED_VARIABLES[var_key.upper()].keys()

    var_keys = [var_key] + list(sum(var_keys, ()))

    for key in var_keys:
        if key in ds.data_vars.keys():
            data = ds[key].values
            break

    return data

# %% [markdown]
# ## 1. Check for matching and equal number of files

# %%
_check_if_files_found()

# %%
DEV_GLOB = [fp for fp in DEV_GLOB if "diff.nc" not in fp]
MAIN_GLOB = [fp for fp in MAIN_GLOB if "diff.nc" not in fp]

# %%
len(DEV_GLOB), len(MAIN_GLOB)
# Out:
# (360, 128)

# %%
missing_dev_files, missing_main_files = _check_if_missing_files()

print(f"Missing dev files: {len(missing_dev_files)}")
print(f"Missing main files: {len(missing_main_files)}")
# Out:
# Missing dev files: 0
# Missing main files: 232

# %% [markdown]
# ### Check missing dev files:

# %%
missing_dev_files
# Out:
# []

# %% [markdown]
# ### Check missing main files:
#
# Results:
#
# - `main` no netCDF saved for set: `area_mean_time_series`
# - `main` no files at all: `lat_lon` ref files (model-only)

# %%
missing_main_files
# Out:
# ['/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FLUT/FLUT-20N50N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FLUT/FLUT-20S20N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FLUT/FLUT-50N90N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FLUT/FLUT-50S20S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FLUT/FLUT-90S50S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FLUT/FLUT-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FLUT/FLUT-land_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FLUT/FLUT-ocean_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FSNTOA/FSNTOA-20N50N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FSNTOA/FSNTOA-20S20N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FSNTOA/FSNTOA-50N90N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FSNTOA/FSNTOA-50S20S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FSNTOA/FSNTOA-90S50S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FSNTOA/FSNTOA-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FSNTOA/FSNTOA-land_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/FSNTOA/FSNTOA-ocean_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LHFLX/LHFLX-20N50N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LHFLX/LHFLX-20S20N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LHFLX/LHFLX-50N90N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LHFLX/LHFLX-50S20S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LHFLX/LHFLX-90S50S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LHFLX/LHFLX-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LHFLX/LHFLX-land_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LHFLX/LHFLX-ocean_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LWCF/LWCF-20N50N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LWCF/LWCF-20S20N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LWCF/LWCF-50N90N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LWCF/LWCF-50S20S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LWCF/LWCF-90S50S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LWCF/LWCF-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LWCF/LWCF-land_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/LWCF/LWCF-ocean_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/PRECT/PRECT-20N50N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/PRECT/PRECT-20S20N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/PRECT/PRECT-50N90N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/PRECT/PRECT-50S20S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/PRECT/PRECT-90S50S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/PRECT/PRECT-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/PRECT/PRECT-land_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/PRECT/PRECT-ocean_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/QFLX/QFLX-20N50N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/QFLX/QFLX-20S20N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/QFLX/QFLX-50N90N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/QFLX/QFLX-50S20S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/QFLX/QFLX-90S50S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/QFLX/QFLX-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/QFLX/QFLX-land_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/QFLX/QFLX-ocean_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SHFLX/SHFLX-20N50N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SHFLX/SHFLX-20S20N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SHFLX/SHFLX-50N90N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SHFLX/SHFLX-50S20S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SHFLX/SHFLX-90S50S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SHFLX/SHFLX-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SHFLX/SHFLX-land_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SHFLX/SHFLX-ocean_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SWCF/SWCF-20N50N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SWCF/SWCF-20S20N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SWCF/SWCF-50N90N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SWCF/SWCF-50S20S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SWCF/SWCF-90S50S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SWCF/SWCF-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SWCF/SWCF-land_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/SWCF/SWCF-ocean_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/TREFHT/TREFHT-20N50N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/TREFHT/TREFHT-20S20N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/TREFHT/TREFHT-50N90N_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/TREFHT/TREFHT-50S20S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/TREFHT/TREFHT-90S50S_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/TREFHT/TREFHT-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/TREFHT/TREFHT-land_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/area_mean_time_series/TREFHT/TREFHT-ocean_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDO-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDO-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDOC-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDOC-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDO_SRF-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDO_SRF-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-AODVIS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-AODVIS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_CAL-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_CAL-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU1.3_9.4_MODIS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU1.3_9.4_MODIS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU1.3_MODIS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU1.3_MODIS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU9.4_MODIS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU9.4_MODIS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_CAL-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_CAL-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_9.4_MISR-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_9.4_MISR-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_MISR-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_MISR-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU9.4_MISR-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU9.4_MISR-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDMED_CAL-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDMED_CAL-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_CAL-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_CAL-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_ISCCP-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_ISCCP-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MISR-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MISR-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MODIS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MODIS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_ISCCP-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_ISCCP-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MISR-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MISR-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MODIS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MODIS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_ISCCP-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_ISCCP-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MISR-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MISR-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MODIS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MODIS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ERFtot-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ERFtot-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLDS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLDS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLDSC-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLDSC-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLNS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLNS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLNSC-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLNSC-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLUT-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLUT-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLUTC-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLUTC-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSDS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSDS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSDSC-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSDSC-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNS-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNS-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNSC-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNSC-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNTOA-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNTOA-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNTOAC-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNTOAC-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LHFLX-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LHFLX-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LWCF-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LWCF-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LWCFSRF-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LWCFSRF-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NETCF-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NETCF-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NETCF_SRF-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NETCF_SRF-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NET_FLUX_SRF-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NET_FLUX_SRF-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-200-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-200-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-200-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-200-JJA-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-500-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-500-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-500-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-500-JJA-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-850-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-850-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-850-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-OMEGA-850-JJA-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-PRECT-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-PRECT-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-PSL-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-PSL-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-QREFHT-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-QREFHT-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-RESTOM-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-RESTOM-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SHFLX-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SHFLX-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SOLIN-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SOLIN-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SST-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SST-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SWCF-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SWCF-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SWCFSRF-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SWCFSRF-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-T-200-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-T-200-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-T-200-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-T-200-JJA-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-T-850-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-T-850-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-T-850-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-T-850-JJA-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TAUXY-ANN-ocean_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TAUXY-JJA-ocean_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TCO-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TCO-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TGCLDLWP_OCN-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TGCLDLWP_OCN-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TMQ-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TMQ-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFHT-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFHT-ANN-land_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFHT-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFHT-JJA-land_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMNAV-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMNAV-ANN-land_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMNAV-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMNAV-JJA-land_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMXAV-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMXAV-ANN-land_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMXAV-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMXAV-JJA-land_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREF_range-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREF_range-ANN-land_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREF_range-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREF_range-JJA-land_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U-200-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U-200-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U-200-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U-200-JJA-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U-850-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U-850-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U-850-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U-850-JJA-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U10-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U10-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-Z3-500-ANN-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-Z3-500-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-Z3-500-JJA-global_ref.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-Z3-500-JJA-global_test.nc']

# %% [markdown]
# ## 2 Compare the netCDF files between branches
#
# - Compare "ref" and "test" files
# - "diff" files are ignored because getting relative diffs for these does not make sense (relative diff will be above tolerance)

# %%
results = _get_relative_diffs()
# Out:
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-ALBEDO-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDO-ANN-global_test.nc
#     * var_key: ALBEDO
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-ALBEDO-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDO-JJA-global_test.nc
#     * var_key: ALBEDO
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-ALBEDOC-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDOC-ANN-global_test.nc
#     * var_key: ALBEDOC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-ALBEDOC-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDOC-JJA-global_test.nc
#     * var_key: ALBEDOC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-ALBEDO_SRF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDO_SRF-ANN-global_test.nc
#     * var_key: ALBEDO_SRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-ALBEDO_SRF-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ALBEDO_SRF-JJA-global_test.nc
#     * var_key: ALBEDO_SRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-AODVIS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-AODVIS-ANN-global_test.nc
#     * var_key: AODVIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-AODVIS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-AODVIS-JJA-global_test.nc
#     * var_key: AODVIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDHGH_CAL-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_CAL-ANN-global_test.nc
#     * var_key: CLDHGH_CAL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDHGH_CAL-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_CAL-JJA-global_test.nc
#     * var_key: CLDHGH_CAL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDHGH_TAU1.3_9.4_MODIS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU1.3_9.4_MODIS-ANN-global_test.nc
#     * var_key: CLDHGH_TAU1.3_9.4_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDHGH_TAU1.3_9.4_MODIS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU1.3_9.4_MODIS-JJA-global_test.nc
#     * var_key: CLDHGH_TAU1.3_9.4_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDHGH_TAU1.3_MODIS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU1.3_MODIS-ANN-global_test.nc
#     * var_key: CLDHGH_TAU1.3_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDHGH_TAU1.3_MODIS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU1.3_MODIS-JJA-global_test.nc
#     * var_key: CLDHGH_TAU1.3_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDHGH_TAU9.4_MODIS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU9.4_MODIS-ANN-global_test.nc
#     * var_key: CLDHGH_TAU9.4_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDHGH_TAU9.4_MODIS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDHGH_TAU9.4_MODIS-JJA-global_test.nc
#     * var_key: CLDHGH_TAU9.4_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDLOW_CAL-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_CAL-ANN-global_test.nc
#     * var_key: CLDLOW_CAL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDLOW_CAL-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_CAL-JJA-global_test.nc
#     * var_key: CLDLOW_CAL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDLOW_TAU1.3_9.4_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_9.4_MISR-ANN-global_test.nc
#     * var_key: CLDLOW_TAU1.3_9.4_MISR
#
# Not equal to tolerance rtol=1e-05, atol=0
#
# Mismatched elements: 9 / 64800 (0.0139%)
# Max absolute difference: 0.0970192
# Max relative difference: 0.01244658
#  x: array([[ 0.056777,  0.056777,  0.056777, ...,  1.274017,  1.274017,
#          1.274017],
#        [ 0.207892,  0.207774,  0.207536, ...,  1.675944,  1.676576,...
#  y: array([[ 0.056777,  0.056777,  0.056777, ...,  1.274017,  1.274017,
#          1.274017],
#        [ 0.207892,  0.207774,  0.207536, ...,  1.675944,  1.676576,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDLOW_TAU1.3_9.4_MISR-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_9.4_MISR-JJA-global_test.nc
#     * var_key: CLDLOW_TAU1.3_9.4_MISR
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDLOW_TAU1.3_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_MISR-ANN-global_test.nc
#     * var_key: CLDLOW_TAU1.3_MISR
#
# Not equal to tolerance rtol=1e-05, atol=0
#
# Mismatched elements: 9 / 64800 (0.0139%)
# Max absolute difference: 0.0970192
# Max relative difference: 0.00541773
#  x: array([[5.677656e-02, 5.677656e-02, 5.677656e-02, ..., 1.274017e+00,
#         1.274017e+00, 1.274017e+00],
#        [2.078919e-01, 2.077735e-01, 2.075364e-01, ..., 1.675944e+00,...
#  y: array([[5.677656e-02, 5.677656e-02, 5.677656e-02, ..., 1.274017e+00,
#         1.274017e+00, 1.274017e+00],
#        [2.078919e-01, 2.077735e-01, 2.075364e-01, ..., 1.675944e+00,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDLOW_TAU1.3_MISR-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_MISR-JJA-global_test.nc
#     * var_key: CLDLOW_TAU1.3_MISR
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDLOW_TAU9.4_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU9.4_MISR-ANN-global_test.nc
#     * var_key: CLDLOW_TAU9.4_MISR
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDLOW_TAU9.4_MISR-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU9.4_MISR-JJA-global_test.nc
#     * var_key: CLDLOW_TAU9.4_MISR
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDMED_CAL-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDMED_CAL-ANN-global_test.nc
#     * var_key: CLDMED_CAL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDMED_CAL-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDMED_CAL-JJA-global_test.nc
#     * var_key: CLDMED_CAL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_CAL-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_CAL-ANN-global_test.nc
#     * var_key: CLDTOT_CAL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_CAL-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_CAL-JJA-global_test.nc
#     * var_key: CLDTOT_CAL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_ISCCP-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_ISCCP-ANN-global_test.nc
#     * var_key: CLDTOT_TAU1.3_9.4_ISCCP
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_ISCCP-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_ISCCP-JJA-global_test.nc
#     * var_key: CLDTOT_TAU1.3_9.4_ISCCP
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MISR-ANN-global_test.nc
#     * var_key: CLDTOT_TAU1.3_9.4_MISR
#
# Not equal to tolerance rtol=1e-05, atol=0
#
# Mismatched elements: 9 / 64800 (0.0139%)
# Max absolute difference: 0.0970192
# Max relative difference: 0.00456364
#  x: array([[ 4.128816,  4.128816,  4.128816, ...,  7.77411 ,  7.77411 ,
#          7.77411 ],
#        [ 4.164101,  4.164073,  4.164018, ...,  7.538528,  7.538158,...
#  y: array([[ 4.128816,  4.128816,  4.128816, ...,  7.774109,  7.774109,
#          7.774109],
#        [ 4.164101,  4.164073,  4.164018, ...,  7.538528,  7.538157,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MISR-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MISR-JJA-global_test.nc
#     * var_key: CLDTOT_TAU1.3_9.4_MISR
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MODIS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MODIS-ANN-global_test.nc
#     * var_key: CLDTOT_TAU1.3_9.4_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MODIS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MODIS-JJA-global_test.nc
#     * var_key: CLDTOT_TAU1.3_9.4_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_ISCCP-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_ISCCP-ANN-global_test.nc
#     * var_key: CLDTOT_TAU1.3_ISCCP
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_ISCCP-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_ISCCP-JJA-global_test.nc
#     * var_key: CLDTOT_TAU1.3_ISCCP
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MISR-ANN-global_test.nc
#     * var_key: CLDTOT_TAU1.3_MISR
#
# Not equal to tolerance rtol=1e-05, atol=0
#
# Mismatched elements: 9 / 64800 (0.0139%)
# Max absolute difference: 0.09701157
# Max relative difference: 0.00250626
#  x: array([[ 4.134768,  4.134768,  4.134768, ...,  7.843707,  7.843707,
#          7.843707],
#        [ 4.183939,  4.1839  ,  4.183824, ...,  7.598535,  7.598149,...
#  y: array([[ 4.134768,  4.134768,  4.134768, ...,  7.843706,  7.843706,
#          7.843706],
#        [ 4.183939,  4.1839  ,  4.183823, ...,  7.598534,  7.598149,...
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MISR-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MISR-JJA-global_test.nc
#     * var_key: CLDTOT_TAU1.3_MISR
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MODIS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MODIS-ANN-global_test.nc
#     * var_key: CLDTOT_TAU1.3_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MODIS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MODIS-JJA-global_test.nc
#     * var_key: CLDTOT_TAU1.3_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU9.4_ISCCP-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_ISCCP-ANN-global_test.nc
#     * var_key: CLDTOT_TAU9.4_ISCCP
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU9.4_ISCCP-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_ISCCP-JJA-global_test.nc
#     * var_key: CLDTOT_TAU9.4_ISCCP
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MISR-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MISR-ANN-global_test.nc
#     * var_key: CLDTOT_TAU9.4_MISR
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MISR-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MISR-JJA-global_test.nc
#     * var_key: CLDTOT_TAU9.4_MISR
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MODIS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MODIS-ANN-global_test.nc
#     * var_key: CLDTOT_TAU9.4_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MODIS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU9.4_MODIS-JJA-global_test.nc
#     * var_key: CLDTOT_TAU9.4_MODIS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-ERFtot-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ERFtot-ANN-global_test.nc
#     * var_key: ERFtot
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-ERFtot-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-ERFtot-JJA-global_test.nc
#     * var_key: ERFtot
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLDS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLDS-ANN-global_test.nc
#     * var_key: FLDS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLDS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLDS-JJA-global_test.nc
#     * var_key: FLDS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLDSC-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLDSC-ANN-global_test.nc
#     * var_key: FLDSC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLDSC-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLDSC-JJA-global_test.nc
#     * var_key: FLDSC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLNS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLNS-ANN-global_test.nc
#     * var_key: FLNS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLNS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLNS-JJA-global_test.nc
#     * var_key: FLNS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLNSC-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLNSC-ANN-global_test.nc
#     * var_key: FLNSC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLNSC-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLNSC-JJA-global_test.nc
#     * var_key: FLNSC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLUT-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLUT-ANN-global_test.nc
#     * var_key: FLUT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLUT-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLUT-JJA-global_test.nc
#     * var_key: FLUT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLUTC-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLUTC-ANN-global_test.nc
#     * var_key: FLUTC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FLUTC-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FLUTC-JJA-global_test.nc
#     * var_key: FLUTC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSDS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSDS-ANN-global_test.nc
#     * var_key: FSDS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSDS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSDS-JJA-global_test.nc
#     * var_key: FSDS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSDSC-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSDSC-ANN-global_test.nc
#     * var_key: FSDSC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSDSC-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSDSC-JJA-global_test.nc
#     * var_key: FSDSC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSNS-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNS-ANN-global_test.nc
#     * var_key: FSNS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSNS-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNS-JJA-global_test.nc
#     * var_key: FSNS
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSNSC-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNSC-ANN-global_test.nc
#     * var_key: FSNSC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSNSC-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNSC-JJA-global_test.nc
#     * var_key: FSNSC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSNTOA-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNTOA-ANN-global_test.nc
#     * var_key: FSNTOA
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSNTOA-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNTOA-JJA-global_test.nc
#     * var_key: FSNTOA
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSNTOAC-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNTOAC-ANN-global_test.nc
#     * var_key: FSNTOAC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-FSNTOAC-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-FSNTOAC-JJA-global_test.nc
#     * var_key: FSNTOAC
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-LHFLX-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LHFLX-ANN-global_test.nc
#     * var_key: LHFLX
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-LHFLX-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LHFLX-JJA-global_test.nc
#     * var_key: LHFLX
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-LWCF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LWCF-ANN-global_test.nc
#     * var_key: LWCF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-LWCF-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LWCF-JJA-global_test.nc
#     * var_key: LWCF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-LWCFSRF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LWCFSRF-ANN-global_test.nc
#     * var_key: LWCFSRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-LWCFSRF-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-LWCFSRF-JJA-global_test.nc
#     * var_key: LWCFSRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-NETCF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NETCF-ANN-global_test.nc
#     * var_key: NETCF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-NETCF-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NETCF-JJA-global_test.nc
#     * var_key: NETCF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-NETCF_SRF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NETCF_SRF-ANN-global_test.nc
#     * var_key: NETCF_SRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-NETCF_SRF-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NETCF_SRF-JJA-global_test.nc
#     * var_key: NETCF_SRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-NET_FLUX_SRF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NET_FLUX_SRF-ANN-global_test.nc
#     * var_key: NET_FLUX_SRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-NET_FLUX_SRF-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-NET_FLUX_SRF-JJA-global_test.nc
#     * var_key: NET_FLUX_SRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-PRECT-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-PRECT-ANN-global_test.nc
#     * var_key: PRECT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-PRECT-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-PRECT-JJA-global_test.nc
#     * var_key: PRECT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-PSL-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-PSL-ANN-global_test.nc
#     * var_key: PSL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-PSL-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-PSL-JJA-global_test.nc
#     * var_key: PSL
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-QREFHT-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-QREFHT-ANN-global_test.nc
#     * var_key: QREFHT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-QREFHT-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-QREFHT-JJA-global_test.nc
#     * var_key: QREFHT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-RESTOM-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-RESTOM-ANN-global_test.nc
#     * var_key: RESTOM
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-RESTOM-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-RESTOM-JJA-global_test.nc
#     * var_key: RESTOM
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SHFLX-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SHFLX-ANN-global_test.nc
#     * var_key: SHFLX
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SHFLX-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SHFLX-JJA-global_test.nc
#     * var_key: SHFLX
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SOLIN-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SOLIN-ANN-global_test.nc
#     * var_key: SOLIN
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SOLIN-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SOLIN-JJA-global_test.nc
#     * var_key: SOLIN
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SST-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SST-ANN-global_test.nc
#     * var_key: SST
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SST-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SST-JJA-global_test.nc
#     * var_key: SST
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SWCF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SWCF-ANN-global_test.nc
#     * var_key: SWCF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SWCF-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SWCF-JJA-global_test.nc
#     * var_key: SWCF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SWCFSRF-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SWCFSRF-ANN-global_test.nc
#     * var_key: SWCFSRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-SWCFSRF-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-SWCFSRF-JJA-global_test.nc
#     * var_key: SWCFSRF
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TAUXY-ANN-ocean_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TAUXY-ANN-ocean_test.nc
#     * var_key: TAUXY
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TAUXY-JJA-ocean_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TAUXY-JJA-ocean_test.nc
#     * var_key: TAUXY
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TCO-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TCO-ANN-global_test.nc
#     * var_key: TCO
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TCO-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TCO-JJA-global_test.nc
#     * var_key: TCO
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TGCLDLWP_OCN-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TGCLDLWP_OCN-ANN-global_test.nc
#     * var_key: TGCLDLWP_OCN
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TGCLDLWP_OCN-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TGCLDLWP_OCN-JJA-global_test.nc
#     * var_key: TGCLDLWP_OCN
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TMQ-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TMQ-ANN-global_test.nc
#     * var_key: TMQ
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TMQ-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TMQ-JJA-global_test.nc
#     * var_key: TMQ
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFHT-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFHT-ANN-global_test.nc
#     * var_key: TREFHT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFHT-ANN-land_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFHT-ANN-land_test.nc
#     * var_key: TREFHT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFHT-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFHT-JJA-global_test.nc
#     * var_key: TREFHT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFHT-JJA-land_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFHT-JJA-land_test.nc
#     * var_key: TREFHT
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFMNAV-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMNAV-ANN-global_test.nc
#     * var_key: TREFMNAV
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFMNAV-ANN-land_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMNAV-ANN-land_test.nc
#     * var_key: TREFMNAV
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFMNAV-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMNAV-JJA-global_test.nc
#     * var_key: TREFMNAV
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFMNAV-JJA-land_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMNAV-JJA-land_test.nc
#     * var_key: TREFMNAV
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFMXAV-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMXAV-ANN-global_test.nc
#     * var_key: TREFMXAV
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFMXAV-ANN-land_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMXAV-ANN-land_test.nc
#     * var_key: TREFMXAV
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFMXAV-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMXAV-JJA-global_test.nc
#     * var_key: TREFMXAV
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREFMXAV-JJA-land_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREFMXAV-JJA-land_test.nc
#     * var_key: TREFMXAV
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREF_range-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREF_range-ANN-global_test.nc
#     * var_key: TREF_range
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREF_range-ANN-land_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREF_range-ANN-land_test.nc
#     * var_key: TREF_range
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREF_range-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREF_range-JJA-global_test.nc
#     * var_key: TREF_range
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-TREF_range-JJA-land_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-TREF_range-JJA-land_test.nc
#     * var_key: TREF_range
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-U10-ANN-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U10-ANN-global_test.nc
#     * var_key: U10
#     * All close and within relative tolerance (1e-05)
# Comparing:
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/843-migration-phase3-no-obs/lat_lon/model_vs_model/-U10-JJA-global_test.nc
#     * /global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-U10-JJA-global_test.nc
#     * var_key: U10
#     * All close and within relative tolerance (1e-05)

# %%
(
    missing_files,
    matching_files,
    mismatch_errors,
    not_equal_errors,
    key_errors,
) = results.values()

# %%
sum_files_compared = (
    len(matching_files)
    + len(mismatch_errors)
    + len(not_equal_errors)
    + len(key_errors)
    + len(missing_files)
)

# %% [markdown]
# ### Close results

# %%
pct_match = (len(matching_files) / sum_files_compared) * 100

print(
    f"Matching files count: {len(matching_files)}/{sum_files_compared}, {pct_match:.2f}%"
)
# Out:
# Matching files count: 124/128, 96.88%

# %%
pct_missing = (len(missing_files) / sum_files_compared) * 100

print(
    f"Missing files count: {len(missing_files)}/{sum_files_compared}, {pct_missing:.2f}%"
)
# Out:
# Missing files count: 0/128, 0.00%

# %% [markdown]
# ### `NaN` Mismatching Errors (Not concerned)
#
# I found these `nan` mismatch errors occur due to either:
#
# 1. Regional subsetting on "ccb" flag in CDAT adding a coordinate points -- removing these coordinates results in matching results
# 2. Slightly different masking in the data between xCDAT and CDAT via xESMF/ESMF -- same number of nans just slightly shifted over some coordinates points
#
# - Refer to PR [#794](https://github.com/E3SM-Project/e3sm_diags/pull/794)

# %%
pct_mismatch = (len(mismatch_errors) / sum_files_compared) * 100

print(
    f"Mismatch errors count: {len(mismatch_errors)}/{sum_files_compared}, {pct_missing:.2f}%"
)
# Out:
# Mismatch errors count: 0/128, 0.00%

# %% [markdown]
# ### Not Equal Errors (Not concerned)
#
# Refer to GH PR [#794](https://github.com/E3SM-Project/e3sm_diags/pull/794)
#
# > The following variables have large diffs due to a bug on main: MISRCOSP-CLDLOW_TAU1.3_9.4_MISR, MISRCOSP-CLDLOW_TAU1.3_MISR, MISRCOSP-CLDLOW_TAU9.4_MISR. I believe this branch is doing the correct thing. We can revisit the comparison for these variables once the issue below is fixed on main.
# >
# > [\[Bug\]: Silent bug in adjust_prs_val_units() conditional where if prs_val0: will be False if prs_val0 is 0 #797](https://github.com/E3SM-Project/e3sm_diags/issues/797)

# %%
pct_not_equal_errors = (len(not_equal_errors) / sum_files_compared) * 100

print(
    f"Not equal to tolerance count: {len(not_equal_errors)}/{sum_files_compared}, {pct_not_equal_errors:.2f}%"
)
# Out:
# Not equal to tolerance count: 4/128, 3.12%

# %%
not_equal_errors
# Out:
# ['/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_9.4_MISR-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDLOW_TAU1.3_MISR-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_9.4_MISR-ANN-global_test.nc',
#  '/global/cfs/cdirs/e3sm/www/cdat-migration-fy24/main/v2_9_0_all_sets_model_vs_model/lat_lon/model_vs_model/-CLDTOT_TAU1.3_MISR-ANN-global_test.nc']

# %% [markdown]
# ### Key Errors (None)

# %%
print(f"Key errors count: {len(key_errors)}")
# Out:
# Key errors count: 0

# %% [markdown]
# ### Results
#
# All files are within rtol 1e-5, so the changes should be good to go.
